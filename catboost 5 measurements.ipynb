# %%
import numpy as np 
import pandas as pd 
from catboost import CatBoostRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error
from sklearn.multioutput import MultiOutputRegressor
import seaborn as sns

# %%
df = pd.read_excel('2015_7차_직접측정 데이터.xlsx')

# %% [markdown]
# target1: 얼굴수직길이
# target2: 머리너비
# target3: 머리수직길이
# target4: 아래턱사이너비
# target5: 머리둘레
#
# we already have models for target1,target2.
#
# The notebook below produces models for target3, target4, target5

# %% [markdown]
# ## For using all 5 features

# %%
gender = df['ⓞ_02_성별'].values 
age = df['ⓞ_06_나이_반올림'].values
height = df['①_003_키'].values
weight = df['①_031_몸무게'].values 
shoe = df['①_119_발직선길이'].values 
target1 = df['①_094_얼굴수직길이'].values
target2 = df['①_115_머리너비'].values
target3 = df['①_093_머리수직길이'].values
target4 = df['①_117_아래턱사이너비'].values 
target5 = df['①_111_머리둘레'].values

# %%
gender_encoded = [] 
for i in range(len(gender)): 
    if gender[i] == '남': 
        gender_encoded.append(0) 
    else: 
        gender_encoded.append(1) 
gender_encoded = np.asarray(gender_encoded)

# %%
train = pd.DataFrame({'gender':gender_encoded,
                      'age':age,
                      'height': height, 
                      'weight': weight, 
                      'shoe_size': shoe, 
                      'target1': target1, 
                      'target2': target2, 
                      'target3': target3, 
                      'target4': target4, 
                      'target5': target5
                     })

# %%
def produce_models(target_name): 
    target_names = ['target1','target2','target3','target4','target5'] 
    x_train = train.drop(columns=target_names)
    y_train = train[target_name] 
    temp = pd.concat([x_train,y_train],axis=1)
    temp = temp.dropna()
    x_train = temp.drop(columns=[target_name])
    y_train = temp[target_name] 
    print("fitting model...")
    models = []

    kfold = KFold(n_splits = 5, shuffle = True, random_state = 888) 
    for idx, (train_idx, val_idx) in enumerate(kfold.split(x_train, y_train)):  
        print("validating on fold {}...".format(idx+1))
        train_x, val_x = x_train.iloc[train_idx,:], x_train.iloc[val_idx,:]
        train_y, val_y = y_train.iloc[train_idx], y_train.iloc[val_idx] 
        model = CatBoostRegressor(iterations = 10000,
                              learning_rate = 0.01, 
                              loss_function = 'RMSE', 
                              eval_metric = 'RMSE',
                              verbose = 2500, 
                              use_best_model = True,
                              random_seed = 999)  
    
        model.fit(train_x, train_y, eval_set = (val_x, val_y)) 
    
        models.append(model) 
    
    print("saving models...") 
    for idx,model in enumerate(models):  
        model.save_model(target_name + "_model_" + str(idx+1)) 
        
    return models

# %%
produce_models('target1')
# Out:
# fitting model...
# validating on fold 1...
# 0:	learn: 7.3253502	test: 7.0934690	best: 7.0934690 (0)	total: 4.5ms	remaining: 45s
# 2500:	learn: 5.2958141	test: 5.7038761	best: 5.6959675 (1880)	total: 3.89s	remaining: 11.7s
# 5000:	learn: 4.8261555	test: 5.7540414	best: 5.6959675 (1880)	total: 8.63s	remaining: 8.63s
# 7500:	learn: 4.4689092	test: 5.8070423	best: 5.6959675 (1880)	total: 13.7s	remaining: 4.58s
# 9999:	learn: 4.1800609	test: 5.8569251	best: 5.6959675 (1880)	total: 18s	remaining: 0us
#
# bestTest = 5.695967547
# bestIteration = 1880
#
# Shrink model to first 1881 iterations.
# validating on fold 2...
# 0:	learn: 7.2336802	test: 7.4588208	best: 7.4588208 (0)	total: 1.78ms	remaining: 17.8s
# 2500:	learn: 5.2616999	test: 6.1138688	best: 6.0539788 (497)	total: 4.85s	remaining: 14.5s
# 5000:	learn: 4.7944642	test: 6.1903731	best: 6.0539788 (497)	total: 9.74s	remaining: 9.74s
# 7500:	learn: 4.4417082	test: 6.2561284	best: 6.0539788 (497)	total: 14.4s	remaining: 4.78s
# 9999:	learn: 4.1664834	test: 6.3062966	best: 6.0539788 (497)	total: 19.1s	remaining: 0us
#
# bestTest = 6.05397884
# bestIteration = 497
#
# Shrink model to first 498 iterations.
# validating on fold 3...
# 0:	learn: 7.2566974	test: 7.3687230	best: 7.3687230 (0)	total: 2.7ms	remaining: 27s
# 2500:	learn: 5.2735715	test: 6.0524908	best: 6.0396965 (1316)	total: 4.5s	remaining: 13.5s
# 5000:	learn: 4.8314396	test: 6.0881586	best: 6.0396965 (1316)	total: 9.98s	remaining: 9.97s
# 7500:	learn: 4.4920155	test: 6.1324632	best: 6.0396965 (1316)	total: 15.1s	remaining: 5.02s
# 9999:	learn: 4.2077510	test: 6.1666232	best: 6.0396965 (1316)	total: 19.9s	remaining: 0us
#
# bestTest = 6.039696508
# bestIteration = 1316
#
# Shrink model to first 1317 iterations.
# validating on fold 4...
# 0:	learn: 7.2877251	test: 7.2467429	best: 7.2467429 (0)	total: 1.8ms	remaining: 18.1s
# 2500:	learn: 5.2972167	test: 5.7443019	best: 5.7407226 (1969)	total: 4.2s	remaining: 12.6s
# 5000:	learn: 4.8491506	test: 5.7691422	best: 5.7407226 (1969)	total: 8.59s	remaining: 8.58s
# 7500:	learn: 4.5019877	test: 5.8045132	best: 5.7407226 (1969)	total: 13.5s	remaining: 4.5s
# 9999:	learn: 4.2193066	test: 5.8385435	best: 5.7407226 (1969)	total: 18.5s	remaining: 0us
#
# bestTest = 5.740722635
# bestIteration = 1969
#
# Shrink model to first 1970 iterations.
# validating on fold 5...
# 0:	learn: 7.2908474	test: 7.2326964	best: 7.2326964 (0)	total: 1.57ms	remaining: 15.7s
# 2500:	learn: 5.2684800	test: 6.0121282	best: 5.9395943 (525)	total: 4.82s	remaining: 14.5s
# 5000:	learn: 4.7904663	test: 6.0875378	best: 5.9395943 (525)	total: 9.52s	remaining: 9.51s
# 7500:	learn: 4.4290802	test: 6.1361708	best: 5.9395943 (525)	total: 13.5s	remaining: 4.5s
# 9999:	learn: 4.1438345	test: 6.1819137	best: 5.9395943 (525)	total: 17.6s	remaining: 0us
#
# bestTest = 5.939594304
# bestIteration = 525
#
# Shrink model to first 526 iterations.
# saving models...
# [<catboost.core.CatBoostRegressor at 0x7f86f7d607f0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f0725700>,
#  <catboost.core.CatBoostRegressor at 0x7f86f55c3b20>,
#  <catboost.core.CatBoostRegressor at 0x7f86f7cc57c0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f6c2d670>]

# %%
produce_models('target2')
# Out:
# fitting model...
# validating on fold 1...
# 0:	learn: 7.1848582	test: 7.1864708	best: 7.1864708 (0)	total: 3.04ms	remaining: 30.4s
# 2500:	learn: 5.3747617	test: 5.8963681	best: 5.8322841 (552)	total: 5.51s	remaining: 16.5s
# 5000:	learn: 4.9284305	test: 5.9756803	best: 5.8322841 (552)	total: 9.98s	remaining: 9.98s
# 7500:	learn: 4.5746114	test: 6.0407675	best: 5.8322841 (552)	total: 14.9s	remaining: 4.97s
# 9999:	learn: 4.2842944	test: 6.0952727	best: 5.8322841 (552)	total: 19.6s	remaining: 0us
#
# bestTest = 5.832284063
# bestIteration = 552
#
# Shrink model to first 553 iterations.
# validating on fold 2...
# 0:	learn: 7.1971305	test: 7.1361163	best: 7.1361163 (0)	total: 1.83ms	remaining: 18.3s
# 2500:	learn: 5.3886376	test: 5.9256471	best: 5.8567414 (736)	total: 4.56s	remaining: 13.7s
# 5000:	learn: 4.9293153	test: 6.0368179	best: 5.8567414 (736)	total: 8.87s	remaining: 8.87s
# 7500:	learn: 4.5638686	test: 6.1229810	best: 5.8567414 (736)	total: 13.4s	remaining: 4.45s
# 9999:	learn: 4.2675397	test: 6.1956109	best: 5.8567414 (736)	total: 18s	remaining: 0us
#
# bestTest = 5.856741363
# bestIteration = 736
#
# Shrink model to first 737 iterations.
# validating on fold 3...
# 0:	learn: 7.2152513	test: 7.0617320	best: 7.0617320 (0)	total: 2.67ms	remaining: 26.7s
# 2500:	learn: 5.3362678	test: 5.9552255	best: 5.8747774 (366)	total: 4.85s	remaining: 14.5s
# 5000:	learn: 4.8864142	test: 6.0422334	best: 5.8747774 (366)	total: 9.39s	remaining: 9.39s
# 7500:	learn: 4.5341368	test: 6.1170993	best: 5.8747774 (366)	total: 14.1s	remaining: 4.7s
# 9999:	learn: 4.2318456	test: 6.1936042	best: 5.8747774 (366)	total: 18.9s	remaining: 0us
#
# bestTest = 5.874777428
# bestIteration = 366
#
# Shrink model to first 367 iterations.
# validating on fold 4...
# 0:	learn: 7.1654135	test: 7.2635831	best: 7.2635831 (0)	total: 2.35ms	remaining: 23.5s
# 2500:	learn: 5.3287108	test: 6.0435359	best: 5.9968367 (469)	total: 4.38s	remaining: 13.1s
# 5000:	learn: 4.8691154	test: 6.0908522	best: 5.9968367 (469)	total: 9.69s	remaining: 9.69s
# 7500:	learn: 4.5132531	test: 6.1312682	best: 5.9968367 (469)	total: 14s	remaining: 4.67s
# 9999:	learn: 4.2237928	test: 6.1700760	best: 5.9968367 (469)	total: 18.2s	remaining: 0us
#
# bestTest = 5.996836705
# bestIteration = 469
#
# Shrink model to first 470 iterations.
# validating on fold 5...
# 0:	learn: 7.1613293	test: 7.2785136	best: 7.2785136 (0)	total: 1.67ms	remaining: 16.7s
# 2500:	learn: 5.3090842	test: 6.0859361	best: 6.0226768 (389)	total: 4.13s	remaining: 12.4s
# 5000:	learn: 4.8533117	test: 6.1748066	best: 6.0226768 (389)	total: 8.39s	remaining: 8.39s
# 7500:	learn: 4.5149694	test: 6.2445729	best: 6.0226768 (389)	total: 12.5s	remaining: 4.17s
# 9999:	learn: 4.2297404	test: 6.2925405	best: 6.0226768 (389)	total: 16.7s	remaining: 0us
#
# bestTest = 6.0226768
# bestIteration = 389
#
# Shrink model to first 390 iterations.
# saving models...
# [<catboost.core.CatBoostRegressor at 0x7f86f3fb8160>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3e5abb0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3e5afd0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb80a0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3e5ae50>]

# %%
produce_models('target3')
# Out:
# fitting model...
# validating on fold 1...
# 0:	learn: 13.4280395	test: 13.4678011	best: 13.4678011 (0)	total: 55ms	remaining: 9m 9s
# 2500:	learn: 8.1412283	test: 9.2294239	best: 9.1556414 (492)	total: 4.11s	remaining: 12.3s
# 5000:	learn: 7.4943182	test: 9.3307951	best: 9.1556414 (492)	total: 8.04s	remaining: 8.04s
# 7500:	learn: 6.9766757	test: 9.4323321	best: 9.1556414 (492)	total: 12.2s	remaining: 4.07s
# 9999:	learn: 6.5370712	test: 9.5286139	best: 9.1556414 (492)	total: 16.3s	remaining: 0us
#
# bestTest = 9.155641387
# bestIteration = 492
#
# Shrink model to first 493 iterations.
# validating on fold 2...
# 0:	learn: 13.4316773	test: 13.4537413	best: 13.4537413 (0)	total: 1.9ms	remaining: 19s
# 2500:	learn: 8.1965842	test: 9.0545409	best: 8.9548229 (685)	total: 4.38s	remaining: 13.1s
# 5000:	learn: 7.5323515	test: 9.1953569	best: 8.9548229 (685)	total: 9.01s	remaining: 9.01s
# 7500:	learn: 7.0033688	test: 9.3035535	best: 8.9548229 (685)	total: 13.4s	remaining: 4.45s
# 9999:	learn: 6.5543670	test: 9.3944363	best: 8.9548229 (685)	total: 17.4s	remaining: 0us
#
# bestTest = 8.954822852
# bestIteration = 685
#
# Shrink model to first 686 iterations.
# validating on fold 3...
# 0:	learn: 13.4027086	test: 13.5687396	best: 13.5687396 (0)	total: 6.42ms	remaining: 1m 4s
# 2500:	learn: 8.1395388	test: 9.1376501	best: 9.0538192 (696)	total: 4.14s	remaining: 12.4s
# 5000:	learn: 7.4797681	test: 9.2350593	best: 9.0538192 (696)	total: 8.58s	remaining: 8.58s
# 7500:	learn: 6.9551173	test: 9.3145631	best: 9.0538192 (696)	total: 13.5s	remaining: 4.5s
# 9999:	learn: 6.5298129	test: 9.3869497	best: 9.0538192 (696)	total: 19.9s	remaining: 0us
#
# bestTest = 9.053819194
# bestIteration = 696
#
# Shrink model to first 697 iterations.
# validating on fold 4...
# 0:	learn: 13.4065941	test: 13.5537945	best: 13.5537945 (0)	total: 1.66ms	remaining: 16.6s
# 2500:	learn: 8.1485153	test: 9.2176121	best: 9.1277498 (694)	total: 5.14s	remaining: 15.4s
# 5000:	learn: 7.4838971	test: 9.3108562	best: 9.1277498 (694)	total: 9.42s	remaining: 9.41s
# 7500:	learn: 6.9735700	test: 9.3991980	best: 9.1277498 (694)	total: 14.8s	remaining: 4.95s
# 9999:	learn: 6.5474619	test: 9.4799249	best: 9.1277498 (694)	total: 19.6s	remaining: 0us
#
# bestTest = 9.127749754
# bestIteration = 694
#
# Shrink model to first 695 iterations.
# validating on fold 5...
# 0:	learn: 13.5093113	test: 13.1366688	best: 13.1366688 (0)	total: 1.71ms	remaining: 17.1s
# 2500:	learn: 8.2227058	test: 8.8587010	best: 8.8156461 (996)	total: 4.52s	remaining: 13.6s
# 5000:	learn: 7.5235692	test: 8.9905080	best: 8.8156461 (996)	total: 10.1s	remaining: 10.1s
# 7500:	learn: 6.9885328	test: 9.1043193	best: 8.8156461 (996)	total: 14.7s	remaining: 4.88s
# 9999:	learn: 6.5595893	test: 9.2028916	best: 8.8156461 (996)	total: 19.1s	remaining: 0us
#
# bestTest = 8.815646073
# bestIteration = 996
#
# Shrink model to first 997 iterations.
# saving models...
# [<catboost.core.CatBoostRegressor at 0x7f86f6c37a00>,
#  <catboost.core.CatBoostRegressor at 0x7f86f6c37b80>,
#  <catboost.core.CatBoostRegressor at 0x7f86f6c2c760>,
#  <catboost.core.CatBoostRegressor at 0x7f86f6c373d0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb85b0>]

# %%
produce_models('target4')
# Out:
# fitting model...
# validating on fold 1...
# 0:	learn: 8.4139119	test: 8.4675934	best: 8.4675934 (0)	total: 4.76ms	remaining: 47.6s
# 2500:	learn: 6.7040603	test: 7.4624043	best: 7.4371550 (1252)	total: 4.48s	remaining: 13.4s
# 5000:	learn: 6.0980306	test: 7.5478761	best: 7.4371550 (1252)	total: 9.22s	remaining: 9.21s
# 7500:	learn: 5.6447238	test: 7.6197851	best: 7.4371550 (1252)	total: 14.1s	remaining: 4.71s
# 9999:	learn: 5.2740362	test: 7.6742381	best: 7.4371550 (1252)	total: 18.5s	remaining: 0us
#
# bestTest = 7.437154986
# bestIteration = 1252
#
# Shrink model to first 1253 iterations.
# validating on fold 2...
# 0:	learn: 8.4240275	test: 8.4331990	best: 8.4331990 (0)	total: 1.79ms	remaining: 17.9s
# 2500:	learn: 6.7023024	test: 7.4616509	best: 7.4320705 (1163)	total: 4.3s	remaining: 12.9s
# 5000:	learn: 6.1270330	test: 7.5418322	best: 7.4320705 (1163)	total: 8.54s	remaining: 8.54s
# 7500:	learn: 5.6736904	test: 7.6066402	best: 7.4320705 (1163)	total: 13.4s	remaining: 4.47s
# 9999:	learn: 5.3106063	test: 7.6615437	best: 7.4320705 (1163)	total: 19.4s	remaining: 0us
#
# bestTest = 7.43207048
# bestIteration = 1163
#
# Shrink model to first 1164 iterations.
# validating on fold 3...
# 0:	learn: 8.4376446	test: 8.3686366	best: 8.3686366 (0)	total: 2.97ms	remaining: 29.7s
# 2500:	learn: 6.6876587	test: 7.4938772	best: 7.4544003 (1018)	total: 5.11s	remaining: 15.3s
# 5000:	learn: 6.1208842	test: 7.5859901	best: 7.4544003 (1018)	total: 10.8s	remaining: 10.8s
# 7500:	learn: 5.6696106	test: 7.6656555	best: 7.4544003 (1018)	total: 17.2s	remaining: 5.74s
# 9999:	learn: 5.3005702	test: 7.7359175	best: 7.4544003 (1018)	total: 22.8s	remaining: 0us
#
# bestTest = 7.454400306
# bestIteration = 1018
#
# Shrink model to first 1019 iterations.
# validating on fold 4...
# 0:	learn: 8.3807178	test: 8.5957210	best: 8.5957210 (0)	total: 1.73ms	remaining: 17.3s
# 2500:	learn: 6.6387510	test: 7.7636315	best: 7.7103117 (623)	total: 6.56s	remaining: 19.7s
# 5000:	learn: 6.0550913	test: 7.8348064	best: 7.7103117 (623)	total: 12.7s	remaining: 12.7s
# 7500:	learn: 5.6022782	test: 7.9092849	best: 7.7103117 (623)	total: 17.6s	remaining: 5.87s
# 9999:	learn: 5.2314652	test: 7.9820890	best: 7.7103117 (623)	total: 22.2s	remaining: 0us
#
# bestTest = 7.710311735
# bestIteration = 623
#
# Shrink model to first 624 iterations.
# validating on fold 5...
# 0:	learn: 8.4615902	test: 8.2861156	best: 8.2861156 (0)	total: 1.77ms	remaining: 17.7s
# 2500:	learn: 6.7342752	test: 7.2989164	best: 7.2567245 (868)	total: 5.2s	remaining: 15.6s
# 5000:	learn: 6.1501638	test: 7.3813643	best: 7.2567245 (868)	total: 9.79s	remaining: 9.79s
# 7500:	learn: 5.6850551	test: 7.4688669	best: 7.2567245 (868)	total: 14.7s	remaining: 4.91s
# 9999:	learn: 5.3029455	test: 7.5431046	best: 7.2567245 (868)	total: 18.9s	remaining: 0us
#
# bestTest = 7.256724535
# bestIteration = 868
#
# Shrink model to first 869 iterations.
# saving models...
# [<catboost.core.CatBoostRegressor at 0x7f86f3fb8cd0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8340>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8b20>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8ac0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb87f0>]

# %%
produce_models('target5')
# Out:
# fitting model...
# validating on fold 1...
# 0:	learn: 17.4210240	test: 17.8629494	best: 17.8629494 (0)	total: 4.98ms	remaining: 49.8s
# 2500:	learn: 12.5472872	test: 13.9118578	best: 13.8667336 (997)	total: 4.22s	remaining: 12.7s
# 5000:	learn: 11.5002676	test: 14.0171521	best: 13.8667336 (997)	total: 8.8s	remaining: 8.79s
# 7500:	learn: 10.7142319	test: 14.1345800	best: 13.8667336 (997)	total: 13.7s	remaining: 4.56s
# 9999:	learn: 10.0283311	test: 14.2314836	best: 13.8667336 (997)	total: 17.9s	remaining: 0us
#
# bestTest = 13.8667336
# bestIteration = 997
#
# Shrink model to first 998 iterations.
# validating on fold 2...
# 0:	learn: 17.5093718	test: 17.5163627	best: 17.5163627 (0)	total: 1.74ms	remaining: 17.4s
# 2500:	learn: 12.4972491	test: 13.8435878	best: 13.7234748 (955)	total: 4.27s	remaining: 12.8s
# 5000:	learn: 11.3875768	test: 14.0239326	best: 13.7234748 (955)	total: 8.47s	remaining: 8.47s
# 7500:	learn: 10.5502320	test: 14.1725704	best: 13.7234748 (955)	total: 12.7s	remaining: 4.24s
# 9999:	learn: 9.8699653	test: 14.2920088	best: 13.7234748 (955)	total: 17.2s	remaining: 0us
#
# bestTest = 13.72347481
# bestIteration = 955
#
# Shrink model to first 956 iterations.
# validating on fold 3...
# 0:	learn: 17.5808438	test: 17.2136113	best: 17.2136113 (0)	total: 1.71ms	remaining: 17.1s
# 2500:	learn: 12.3242231	test: 14.5870448	best: 14.2525138 (258)	total: 3.9s	remaining: 11.7s
# 5000:	learn: 11.3136764	test: 14.7499721	best: 14.2525138 (258)	total: 8.23s	remaining: 8.23s
# 7500:	learn: 10.4926340	test: 14.9028593	best: 14.2525138 (258)	total: 12.7s	remaining: 4.22s
# 9999:	learn: 9.8251839	test: 15.0239670	best: 14.2525138 (258)	total: 17.6s	remaining: 0us
#
# bestTest = 14.25251382
# bestIteration = 258
#
# Shrink model to first 259 iterations.
# validating on fold 4...
# 0:	learn: 17.4777617	test: 17.6305629	best: 17.6305629 (0)	total: 1.6ms	remaining: 16s
# 2500:	learn: 12.3978859	test: 14.1511391	best: 14.0793272 (751)	total: 4.64s	remaining: 13.9s
# 5000:	learn: 11.3293357	test: 14.2767485	best: 14.0793272 (751)	total: 9.16s	remaining: 9.15s
# 7500:	learn: 10.5203382	test: 14.3730618	best: 14.0793272 (751)	total: 14.2s	remaining: 4.73s
# 9999:	learn: 9.8479885	test: 14.4737434	best: 14.0793272 (751)	total: 18.9s	remaining: 0us
#
# bestTest = 14.07932718
# bestIteration = 751
#
# Shrink model to first 752 iterations.
# validating on fold 5...
# 0:	learn: 17.5533057	test: 17.3295597	best: 17.3295597 (0)	total: 1.83ms	remaining: 18.3s
# 2500:	learn: 12.5665864	test: 13.8508696	best: 13.6558892 (446)	total: 4.63s	remaining: 13.9s
# 5000:	learn: 11.4814234	test: 14.0339762	best: 13.6558892 (446)	total: 9.14s	remaining: 9.13s
# 7500:	learn: 10.6498098	test: 14.1898865	best: 13.6558892 (446)	total: 13.3s	remaining: 4.42s
# 9999:	learn: 9.9558586	test: 14.3296173	best: 13.6558892 (446)	total: 17.7s	remaining: 0us
#
# bestTest = 13.65588918
# bestIteration = 446
#
# Shrink model to first 447 iterations.
# saving models...
# [<catboost.core.CatBoostRegressor at 0x7f86f3fb8bb0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f6c376d0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8880>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8b50>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8d90>]

# %% [markdown]
# ## For using 3 features
#
# As you can see from the training logs below, the RMSE when using 3 features only is higher.

# %%
gender = df['ⓞ_02_성별'].values 
age = df['ⓞ_06_나이_반올림'].values
height = df['①_003_키'].values
target1 = df['①_094_얼굴수직길이'].values
target2 = df['①_115_머리너비'].values
target3 = df['①_093_머리수직길이'].values
target4 = df['①_117_아래턱사이너비'].values 
target5 = df['①_111_머리둘레'].values

# %%
gender_encoded = [] 
for i in range(len(gender)): 
    if gender[i] == '남': 
        gender_encoded.append(0) 
    else: 
        gender_encoded.append(1) 
gender_encoded = np.asarray(gender_encoded)

# %%
train = pd.DataFrame({'gender':gender_encoded,
                      'age':age,
                      'height': height,
                      'target1': target1, 
                      'target2': target2, 
                      'target3': target3, 
                      'target4': target4, 
                      'target5': target5
                     })

# %%
def produce_models(target_name): 
    target_names = ['target1','target2','target3','target4','target5'] 
    x_train = train.drop(columns=target_names)
    y_train = train[target_name] 
    temp = pd.concat([x_train,y_train],axis=1)
    temp = temp.dropna()
    x_train = temp.drop(columns=[target_name])
    y_train = temp[target_name] 
    print("fitting model...")
    models = []

    kfold = KFold(n_splits = 5, shuffle = True, random_state = 888) 
    for idx, (train_idx, val_idx) in enumerate(kfold.split(x_train, y_train)):  
        print("validating on fold {}...".format(idx+1))
        train_x, val_x = x_train.iloc[train_idx,:], x_train.iloc[val_idx,:]
        train_y, val_y = y_train.iloc[train_idx], y_train.iloc[val_idx] 
        model = CatBoostRegressor(iterations = 10000,
                              learning_rate = 0.01, 
                              loss_function = 'RMSE', 
                              eval_metric = 'RMSE',
                              verbose = 2500, 
                              use_best_model = True,
                              random_seed = 999)  
    
        model.fit(train_x, train_y, eval_set = (val_x, val_y)) 
    
        models.append(model) 
    
    print("saving models...") 
    for idx,model in enumerate(models):  
        model.save_model("3_features_" + target_name + "_model_" + str(idx+1)) 
        
    return models

# %%
produce_models('target1')
# Out:
# fitting model...
# validating on fold 1...
# 0:	learn: 7.3117262	test: 7.1483959	best: 7.1483959 (0)	total: 3.62ms	remaining: 36.2s
# 2500:	learn: 5.7724295	test: 5.9883995	best: 5.9165456 (545)	total: 3.86s	remaining: 11.6s
# 5000:	learn: 5.5222065	test: 6.0603121	best: 5.9165456 (545)	total: 8.23s	remaining: 8.22s
# 7500:	learn: 5.3354762	test: 6.1203858	best: 5.9165456 (545)	total: 12.9s	remaining: 4.31s
# 9999:	learn: 5.1847166	test: 6.1728059	best: 5.9165456 (545)	total: 16.8s	remaining: 0us
#
# bestTest = 5.916545626
# bestIteration = 545
#
# Shrink model to first 546 iterations.
# validating on fold 2...
# 0:	learn: 7.2811446	test: 7.2842966	best: 7.2842966 (0)	total: 1.32ms	remaining: 13.3s
# 2500:	learn: 5.7422825	test: 6.1257898	best: 6.0995565 (623)	total: 3.92s	remaining: 11.8s
# 5000:	learn: 5.5002730	test: 6.1882705	best: 6.0995565 (623)	total: 9.68s	remaining: 9.68s
# 7500:	learn: 5.3227348	test: 6.2464049	best: 6.0995565 (623)	total: 14.8s	remaining: 4.92s
# 9999:	learn: 5.1796052	test: 6.3058866	best: 6.0995565 (623)	total: 21.7s	remaining: 0us
#
# bestTest = 6.09955648
# bestIteration = 623
#
# Shrink model to first 624 iterations.
# validating on fold 3...
# 0:	learn: 7.3306358	test: 7.0723730	best: 7.0723730 (0)	total: 1.69ms	remaining: 16.9s
# 2500:	learn: 5.7607782	test: 6.0729238	best: 6.0331774 (347)	total: 4.94s	remaining: 14.8s
# 5000:	learn: 5.5248082	test: 6.1269269	best: 6.0331774 (347)	total: 10.6s	remaining: 10.6s
# 7500:	learn: 5.3452876	test: 6.1786436	best: 6.0331774 (347)	total: 15.2s	remaining: 5.07s
# 9999:	learn: 5.1991901	test: 6.2252786	best: 6.0331774 (347)	total: 19.1s	remaining: 0us
#
# bestTest = 6.033177385
# bestIteration = 347
#
# Shrink model to first 348 iterations.
# validating on fold 4...
# 0:	learn: 7.2775701	test: 7.2902056	best: 7.2902056 (0)	total: 1.65ms	remaining: 16.5s
# 2500:	learn: 5.7589823	test: 6.0968626	best: 6.0745494 (932)	total: 3.93s	remaining: 11.8s
# 5000:	learn: 5.5259905	test: 6.1340592	best: 6.0745494 (932)	total: 8.56s	remaining: 8.56s
# 7500:	learn: 5.3482594	test: 6.1759146	best: 6.0745494 (932)	total: 13s	remaining: 4.34s
# 9999:	learn: 5.2029806	test: 6.2077044	best: 6.0745494 (932)	total: 17.6s	remaining: 0us
#
# bestTest = 6.074549449
# bestIteration = 932
#
# Shrink model to first 933 iterations.
# validating on fold 5...
# 0:	learn: 7.1970918	test: 7.6018101	best: 7.6018101 (0)	total: 5.01ms	remaining: 50.1s
# 2500:	learn: 5.6915567	test: 6.3540337	best: 6.2651347 (762)	total: 4.55s	remaining: 13.7s
# 5000:	learn: 5.4540523	test: 6.4489484	best: 6.2651347 (762)	total: 9.27s	remaining: 9.27s
# 7500:	learn: 5.2729116	test: 6.5129411	best: 6.2651347 (762)	total: 13.3s	remaining: 4.43s
# 9999:	learn: 5.1302344	test: 6.5681133	best: 6.2651347 (762)	total: 17.3s	remaining: 0us
#
# bestTest = 6.265134744
# bestIteration = 762
#
# Shrink model to first 763 iterations.
# saving models...
# [<catboost.core.CatBoostRegressor at 0x7f86f4c6fb50>,
#  <catboost.core.CatBoostRegressor at 0x7f86f55dd760>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6f0a0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6f8b0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6f580>]

# %%
produce_models('target2')
# Out:
# fitting model...
# validating on fold 1...
# 0:	learn: 7.1655091	test: 7.2740437	best: 7.2740437 (0)	total: 2.47ms	remaining: 24.7s
# 2500:	learn: 5.7172806	test: 6.2732165	best: 6.2011868 (515)	total: 4.13s	remaining: 12.4s
# 5000:	learn: 5.4887419	test: 6.3477185	best: 6.2011868 (515)	total: 8.47s	remaining: 8.46s
# 7500:	learn: 5.3169727	test: 6.4124890	best: 6.2011868 (515)	total: 12.8s	remaining: 4.27s
# 9999:	learn: 5.1782748	test: 6.4682401	best: 6.2011868 (515)	total: 17.5s	remaining: 0us
#
# bestTest = 6.201186782
# bestIteration = 515
#
# Shrink model to first 516 iterations.
# validating on fold 2...
# 0:	learn: 7.1990363	test: 7.1393045	best: 7.1393045 (0)	total: 1.25ms	remaining: 12.5s
# 2500:	learn: 5.7588042	test: 6.1468685	best: 6.0759751 (451)	total: 4.24s	remaining: 12.7s
# 5000:	learn: 5.5269141	test: 6.2195488	best: 6.0759751 (451)	total: 8.9s	remaining: 8.9s
# 7500:	learn: 5.3557246	test: 6.2751393	best: 6.0759751 (451)	total: 13.7s	remaining: 4.58s
# 9999:	learn: 5.2156638	test: 6.3260721	best: 6.0759751 (451)	total: 18.6s	remaining: 0us
#
# bestTest = 6.075975064
# bestIteration = 451
#
# Shrink model to first 452 iterations.
# validating on fold 3...
# 0:	learn: 7.2135183	test: 7.0836609	best: 7.0836609 (0)	total: 3.67ms	remaining: 36.7s
# 2500:	learn: 5.8055331	test: 5.8930606	best: 5.8491306 (632)	total: 4.71s	remaining: 14.1s
# 5000:	learn: 5.5814836	test: 5.9505302	best: 5.8491306 (632)	total: 9.5s	remaining: 9.5s
# 7500:	learn: 5.4140780	test: 6.0115220	best: 5.8491306 (632)	total: 14s	remaining: 4.65s
# 9999:	learn: 5.2738041	test: 6.0686104	best: 5.8491306 (632)	total: 18.1s	remaining: 0us
#
# bestTest = 5.84913058
# bestIteration = 632
#
# Shrink model to first 633 iterations.
# validating on fold 4...
# 0:	learn: 7.1800368	test: 7.2139220	best: 7.2139220 (0)	total: 1.72ms	remaining: 17.2s
# 2500:	learn: 5.7561613	test: 6.1140884	best: 6.0427480 (561)	total: 4.16s	remaining: 12.5s
# 5000:	learn: 5.5263652	test: 6.2096923	best: 6.0427480 (561)	total: 8.77s	remaining: 8.77s
# 7500:	learn: 5.3605638	test: 6.2754352	best: 6.0427480 (561)	total: 14.1s	remaining: 4.68s
# 9999:	learn: 5.2306155	test: 6.3315695	best: 6.0427480 (561)	total: 18.2s	remaining: 0us
#
# bestTest = 6.042748018
# bestIteration = 561
#
# Shrink model to first 562 iterations.
# validating on fold 5...
# 0:	learn: 7.1758197	test: 7.2324755	best: 7.2324755 (0)	total: 1.23ms	remaining: 12.3s
# 2500:	learn: 5.7432035	test: 6.1913694	best: 6.1447442 (811)	total: 4.07s	remaining: 12.2s
# 5000:	learn: 5.5165198	test: 6.2606954	best: 6.1447442 (811)	total: 8.88s	remaining: 8.88s
# 7500:	learn: 5.3493864	test: 6.3200805	best: 6.1447442 (811)	total: 14s	remaining: 4.65s
# 9999:	learn: 5.2121727	test: 6.3735197	best: 6.1447442 (811)	total: 19s	remaining: 0us
#
# bestTest = 6.144744181
# bestIteration = 811
#
# Shrink model to first 812 iterations.
# saving models...
# [<catboost.core.CatBoostRegressor at 0x7f86f4c6f940>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6ffd0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6fd30>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6fbb0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6fa00>]

# %%
produce_models('target3')
# Out:
# fitting model...
# validating on fold 1...
# 0:	learn: 13.4773520	test: 13.2554377	best: 13.2554377 (0)	total: 4.49ms	remaining: 44.9s
# 2500:	learn: 8.6290969	test: 9.3511924	best: 9.2933329 (637)	total: 4.6s	remaining: 13.8s
# 5000:	learn: 8.2970987	test: 9.4676043	best: 9.2933329 (637)	total: 9.2s	remaining: 9.2s
# 7500:	learn: 8.0476014	test: 9.5714813	best: 9.2933329 (637)	total: 13.3s	remaining: 4.44s
# 9999:	learn: 7.8467174	test: 9.6585181	best: 9.2933329 (637)	total: 17.3s	remaining: 0us
#
# bestTest = 9.293332861
# bestIteration = 637
#
# Shrink model to first 638 iterations.
# validating on fold 2...
# 0:	learn: 13.4500372	test: 13.3745390	best: 13.3745390 (0)	total: 1.62ms	remaining: 16.2s
# 2500:	learn: 8.6818985	test: 9.2217703	best: 9.0894962 (605)	total: 3.78s	remaining: 11.3s
# 5000:	learn: 8.3511991	test: 9.3463989	best: 9.0894962 (605)	total: 7.71s	remaining: 7.71s
# 7500:	learn: 8.1037954	test: 9.4579159	best: 9.0894962 (605)	total: 11.6s	remaining: 3.87s
# 9999:	learn: 7.9016805	test: 9.5537798	best: 9.0894962 (605)	total: 15.5s	remaining: 0us
#
# bestTest = 9.089496239
# bestIteration = 605
#
# Shrink model to first 606 iterations.
# validating on fold 3...
# 0:	learn: 13.3952225	test: 13.5951282	best: 13.5951282 (0)	total: 1.97ms	remaining: 19.7s
# 2500:	learn: 8.7338342	test: 8.9418140	best: 8.8985838 (744)	total: 3.77s	remaining: 11.3s
# 5000:	learn: 8.3934988	test: 9.0171705	best: 8.8985838 (744)	total: 7.69s	remaining: 7.69s
# 7500:	learn: 8.1433698	test: 9.0910962	best: 8.8985838 (744)	total: 12.9s	remaining: 4.3s
# 9999:	learn: 7.9431213	test: 9.1677094	best: 8.8985838 (744)	total: 17.9s	remaining: 0us
#
# bestTest = 8.898583821
# bestIteration = 744
#
# Shrink model to first 745 iterations.
# validating on fold 4...
# 0:	learn: 13.3154392	test: 13.9000609	best: 13.9000609 (0)	total: 1.62ms	remaining: 16.2s
# 2500:	learn: 8.6061179	test: 9.4592278	best: 9.3732624 (659)	total: 4.35s	remaining: 13.1s
# 5000:	learn: 8.2563229	test: 9.5660081	best: 9.3732624 (659)	total: 9.5s	remaining: 9.49s
# 7500:	learn: 8.0000942	test: 9.6592419	best: 9.3732624 (659)	total: 14.4s	remaining: 4.79s
# 9999:	learn: 7.7931147	test: 9.7426538	best: 9.3732624 (659)	total: 18.9s	remaining: 0us
#
# bestTest = 9.373262422
# bestIteration = 659
#
# Shrink model to first 660 iterations.
# validating on fold 5...
# 0:	learn: 13.5285813	test: 13.0500967	best: 13.0500967 (0)	total: 2ms	remaining: 20s
# 2500:	learn: 8.6793969	test: 9.1791855	best: 9.0842588 (401)	total: 4.33s	remaining: 13s
# 5000:	learn: 8.3128297	test: 9.3237771	best: 9.0842588 (401)	total: 10.2s	remaining: 10.2s
# 7500:	learn: 8.0450674	test: 9.4496674	best: 9.0842588 (401)	total: 15.1s	remaining: 5.02s
# 9999:	learn: 7.8333185	test: 9.5523686	best: 9.0842588 (401)	total: 22.5s	remaining: 0us
#
# bestTest = 9.084258756
# bestIteration = 401
#
# Shrink model to first 402 iterations.
# saving models...
# [<catboost.core.CatBoostRegressor at 0x7f86f3fb81f0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb86a0>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6f430>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6f550>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6fc10>]

# %%
produce_models('target4')
# Out:
# fitting model...
# validating on fold 1...
# 0:	learn: 8.4237769	test: 8.4501850	best: 8.4501850 (0)	total: 3.37ms	remaining: 33.7s
# 2500:	learn: 7.5501281	test: 8.1597102	best: 8.0898616 (246)	total: 4.98s	remaining: 14.9s
# 5000:	learn: 7.2413237	test: 8.2291002	best: 8.0898616 (246)	total: 9.27s	remaining: 9.27s
# 7500:	learn: 7.0080565	test: 8.2918729	best: 8.0898616 (246)	total: 13.9s	remaining: 4.62s
# 9999:	learn: 6.8172460	test: 8.3511741	best: 8.0898616 (246)	total: 19.9s	remaining: 0us
#
# bestTest = 8.089861593
# bestIteration = 246
#
# Shrink model to first 247 iterations.
# validating on fold 2...
# 0:	learn: 8.4351759	test: 8.4084653	best: 8.4084653 (0)	total: 2.89ms	remaining: 28.9s
# 2500:	learn: 7.5787378	test: 7.9621265	best: 7.8465871 (453)	total: 6.79s	remaining: 20.4s
# 5000:	learn: 7.2442402	test: 8.0944569	best: 7.8465871 (453)	total: 11.4s	remaining: 11.4s
# 7500:	learn: 6.9990542	test: 8.1976876	best: 7.8465871 (453)	total: 15.7s	remaining: 5.23s
# 9999:	learn: 6.8009783	test: 8.2889423	best: 7.8465871 (453)	total: 19.9s	remaining: 0us
#
# bestTest = 7.846587125
# bestIteration = 453
#
# Shrink model to first 454 iterations.
# validating on fold 3...
# 0:	learn: 8.4400435	test: 8.3885783	best: 8.3885783 (0)	total: 2.11ms	remaining: 21.1s
# 2500:	learn: 7.5310934	test: 8.1746194	best: 8.1144924 (295)	total: 4.44s	remaining: 13.3s
# 5000:	learn: 7.2058279	test: 8.2558773	best: 8.1144924 (295)	total: 8.85s	remaining: 8.85s
# 7500:	learn: 6.9599648	test: 8.3253686	best: 8.1144924 (295)	total: 12.9s	remaining: 4.29s
# 9999:	learn: 6.7614563	test: 8.3937478	best: 8.1144924 (295)	total: 17.1s	remaining: 0us
#
# bestTest = 8.114492367
# bestIteration = 295
#
# Shrink model to first 296 iterations.
# validating on fold 4...
# 0:	learn: 8.4270311	test: 8.4415108	best: 8.4415108 (0)	total: 1.71ms	remaining: 17.1s
# 2500:	learn: 7.5857963	test: 8.0352085	best: 7.9556687 (545)	total: 4.15s	remaining: 12.4s
# 5000:	learn: 7.2594990	test: 8.1356786	best: 7.9556687 (545)	total: 8.09s	remaining: 8.09s
# 7500:	learn: 7.0181118	test: 8.2213350	best: 7.9556687 (545)	total: 11.9s	remaining: 3.98s
# 9999:	learn: 6.8174968	test: 8.2962765	best: 7.9556687 (545)	total: 16.6s	remaining: 0us
#
# bestTest = 7.955668662
# bestIteration = 545
#
# Shrink model to first 546 iterations.
# validating on fold 5...
# 0:	learn: 8.4203525	test: 8.4651167	best: 8.4651167 (0)	total: 2.99ms	remaining: 29.9s
# 2500:	learn: 7.5246352	test: 8.2421761	best: 8.1343749 (306)	total: 4.88s	remaining: 14.6s
# 5000:	learn: 7.2133421	test: 8.3481639	best: 8.1343749 (306)	total: 9.27s	remaining: 9.27s
# 7500:	learn: 6.9805845	test: 8.4188157	best: 8.1343749 (306)	total: 13.8s	remaining: 4.59s
# 9999:	learn: 6.7860470	test: 8.4888751	best: 8.1343749 (306)	total: 18.4s	remaining: 0us
#
# bestTest = 8.134374898
# bestIteration = 306
#
# Shrink model to first 307 iterations.
# saving models...
# [<catboost.core.CatBoostRegressor at 0x7f86f4c6f670>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8f40>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8a30>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8100>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8370>]

# %%
produce_models('target5')
# Out:
# fitting model...
# validating on fold 1...
# 0:	learn: 17.6557258	test: 16.9605483	best: 16.9605483 (0)	total: 3.98ms	remaining: 39.8s
# 2500:	learn: 14.2440975	test: 14.5273709	best: 14.3741722 (486)	total: 4.66s	remaining: 14s
# 5000:	learn: 13.6618326	test: 14.7324624	best: 14.3741722 (486)	total: 9.35s	remaining: 9.34s
# 7500:	learn: 13.2418089	test: 14.9111055	best: 14.3741722 (486)	total: 14s	remaining: 4.68s
# 9999:	learn: 12.9019974	test: 15.0648982	best: 14.3741722 (486)	total: 18.3s	remaining: 0us
#
# bestTest = 14.37417222
# bestIteration = 486
#
# Shrink model to first 487 iterations.
# validating on fold 2...
# 0:	learn: 17.4300992	test: 17.8695826	best: 17.8695826 (0)	total: 1.65ms	remaining: 16.5s
# 2500:	learn: 13.9968457	test: 15.5510066	best: 15.4493649 (647)	total: 3.86s	remaining: 11.6s
# 5000:	learn: 13.4376095	test: 15.6938189	best: 15.4493649 (647)	total: 8.11s	remaining: 8.1s
# 7500:	learn: 13.0103692	test: 15.8095685	best: 15.4493649 (647)	total: 12.3s	remaining: 4.11s
# 9999:	learn: 12.6702497	test: 15.9280063	best: 15.4493649 (647)	total: 16.8s	remaining: 0us
#
# bestTest = 15.44936489
# bestIteration = 647
#
# Shrink model to first 648 iterations.
# validating on fold 3...
# 0:	learn: 17.5662127	test: 17.3434993	best: 17.3434993 (0)	total: 1.69ms	remaining: 16.9s
# 2500:	learn: 14.0648316	test: 15.2048395	best: 15.0451247 (278)	total: 4.12s	remaining: 12.3s
# 5000:	learn: 13.4875064	test: 15.4387321	best: 15.0451247 (278)	total: 8.41s	remaining: 8.41s
# 7500:	learn: 13.0689300	test: 15.6122453	best: 15.0451247 (278)	total: 13s	remaining: 4.32s
# 9999:	learn: 12.7330557	test: 15.7546417	best: 15.0451247 (278)	total: 17.1s	remaining: 0us
#
# bestTest = 15.04512469
# bestIteration = 278
#
# Shrink model to first 279 iterations.
# validating on fold 4...
# 0:	learn: 17.3987369	test: 17.9949712	best: 17.9949712 (0)	total: 2.01ms	remaining: 20.1s
# 2500:	learn: 14.0633745	test: 15.1850189	best: 15.0777352 (725)	total: 3.75s	remaining: 11.2s
# 5000:	learn: 13.4925505	test: 15.3339207	best: 15.0777352 (725)	total: 7.56s	remaining: 7.56s
# 7500:	learn: 13.0781709	test: 15.4750711	best: 15.0777352 (725)	total: 11.6s	remaining: 3.88s
# 9999:	learn: 12.7336871	test: 15.5968319	best: 15.0777352 (725)	total: 15.4s	remaining: 0us
#
# bestTest = 15.07773522
# bestIteration = 725
#
# Shrink model to first 726 iterations.
# validating on fold 5...
# 0:	learn: 17.5429170	test: 17.4219311	best: 17.4219311 (0)	total: 1.93ms	remaining: 19.3s
# 2500:	learn: 14.1780940	test: 14.7964636	best: 14.6814066 (868)	total: 3.71s	remaining: 11.1s
# 5000:	learn: 13.6071478	test: 14.9632858	best: 14.6814066 (868)	total: 7.49s	remaining: 7.49s
# 7500:	learn: 13.1730473	test: 15.1069711	best: 14.6814066 (868)	total: 12.1s	remaining: 4.02s
# 9999:	learn: 12.8217658	test: 15.2414339	best: 14.6814066 (868)	total: 16.6s	remaining: 0us
#
# bestTest = 14.68140665
# bestIteration = 868
#
# Shrink model to first 869 iterations.
# saving models...
# [<catboost.core.CatBoostRegressor at 0x7f86f3fb8070>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6f700>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6fd00>,
#  <catboost.core.CatBoostRegressor at 0x7f86f3fb8700>,
#  <catboost.core.CatBoostRegressor at 0x7f86f4c6f4f0>]
